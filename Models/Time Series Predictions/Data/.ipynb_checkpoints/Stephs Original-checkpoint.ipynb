# %% [markdown]
# Kimberly Adams and Stephanie Benavidez
#
# DSC 630 Summer 2023
#
# Course Project: Almonds

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Hide warnings
import warnings
warnings.filterwarnings("ignore")

# Show entire dataframes
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
# read combined data dataset
CombinedData = pd.read_csv("U:\School Homework\Summer 2023\Predictive Analytics\Project DSC630\CombinedAlmondProjectData.csv")

# %% [markdown]
# ###  Creating Subsets for Analysis

# %% [markdown]
# - We will drop the 2022 year due to there only being a single value for that year.
# - We will also create three different sub data sets:
#     - Set One will run from 1961 - 2021 containing 'TempChangeC', 'Yield100GperHa', 'HectaresHarvested',' ExportValue1000USD', and 'ImportTons' since all of these variables are available that far back
#         - This data set will help us address how changing temperatures impact almond crops.  It will also allow us to look at historical profit trends.
#     - Set Two will run from 1991 - 2021 and add the 'ProdUSDperTonne' variable to Set One
#         - This additional variable will help us look at the potential profits that an almond grower could take home from selling their crop
#     - Set Three will run from 2000 - 2020 and add the 'WaterStressPerct' variable as that variable starts at 2000
#         - This last variable allows us to see if there are any significant impacts on harvest due to water scarcity.  This variable is unfortunately only available for such a short period of time.

# %%
# Extract rows for 1961 - 2021
SetOne = CombinedData[CombinedData['Year'] <= 2021]
# Drop incomplete columns
SetOne = SetOne.drop(['ProdUSDperTonne','WaterStressPerct'], axis=1)

# Make sure the variables are numeric
SetOne['Yield100GperHa'] = pd.to_numeric(SetOne['Yield100GperHa'])
SetOne['HectaresHarvested'] = pd.to_numeric(SetOne['HectaresHarvested'])
SetOne['ExportValue1000USD'] = pd.to_numeric(SetOne['ExportValue1000USD'])
SetOne['ImportTons'] = pd.to_numeric(SetOne['ImportTons'])
SetOne
# Out:
#     Year  TempChangeC  Yield100GperHa  HectaresHarvested  ExportValue1000USD  \
# 0   1961        0.950         16669.0            36138.0               170.0
# 1   1962       -0.772         11558.0            37676.0               131.0
# 2   1963       -1.184         13684.0            39578.0               407.0
# 3   1964        0.915         16517.0            41196.0               357.0
# 4   1965        0.753         13932.0            47469.0               372.0
# 5   1966       -1.670         16126.0            47874.0               908.0
# 6   1967        1.652         13781.0            50423.0              1866.0
# 7   1968       -0.076         12362.0            54672.0               690.0
# 8   1969       -0.472         18355.0            60297.0              1146.0
# 9   1970       -1.642         16360.0            68760.0              1729.0
# 10  1971       -1.219         15995.0            76000.0              1079.0
# 11  1972       -0.214         14088.0            80490.0              2993.0
# 12  1973       -0.490         14063.0            86440.0              1897.0
# 13  1974        0.536         18326.0            93560.0              4632.0
# 14  1975        0.808         14417.0           100680.0              3311.0
# 15  1976        0.140         20252.0           104370.0               887.0
# 16  1977       -1.324         20188.0           111890.0              1980.0
# 17  1978       -0.450         10396.0           124520.0              3464.0
# 18  1979       -2.295         21006.0           131160.0              4016.0
# 19  1980        0.538         18137.0           132250.0              3437.0
# 20  1981        2.965         22980.0           132010.0              5227.0
# 21  1982       -1.699         18748.0           137190.0              9446.0
# 22  1983        1.428         12356.0           145680.0              7232.0
# 23  1984       -0.075         28473.0           154180.0              5736.0
# 24  1985        0.269         21268.0           165510.0             10951.0
# 25  1986        2.643         11250.0           168350.0              7416.0
# 26  1987        1.553         29630.0           168750.0              9734.0
# 27  1988       -0.156         26356.0           169560.0             26114.0
# 28  1989        0.822         22317.0           166330.0             26034.0
# 29  1990        2.829         30049.0           166330.0             19761.0
# 30  1991        0.228         22648.0           163900.0             26373.0
# 31  1992        2.217         25401.0           162280.0             30781.0
# 32  1993        0.622         21767.0           167130.0             32435.0
# 33  1994        0.346         30246.0           175230.0             43722.0
# 34  1995        1.825         16316.0           169160.0             47002.0
# 35  1996       -0.279         22258.0           173200.0             52885.0
# 36  1997        0.057         30295.0           181220.0             67533.0
# 37  1998        2.301         20838.0           188600.0             63438.0
# 38  1999        1.374         32063.0           196800.0             51408.0
# 39  2000        1.543         26342.0           202340.0            103563.0
# 40  2001        2.055         28402.0           214483.0            106329.0
# 41  2002        2.783         36275.0           220554.0            112110.0
# 42  2003        2.167         35325.0           222577.0            190452.0
# 43  2004        0.116         34074.0           230671.0            216530.0
# 44  2005        2.174         29969.0           234718.0            293287.0
# 45  2006        3.556         36049.0           234718.0            240514.0
# 46  2007        1.172         46830.0           259002.0            242532.0
# 47  2008        0.206         51238.0           275189.0            335466.0
# 48  2009        0.456         39887.0           291374.0            431156.0
# 49  2010        0.545         45371.0           311608.0            528902.0
# 50  2011        0.638         56883.0           323749.0            652397.0
# 51  2012        1.563         49871.0           331854.0            834701.0
# 52  2013        2.079         50375.0           343983.0            895132.0
# 53  2014        1.972         43897.0           352077.0            883493.0
# 54  2015        2.055         38580.0           372311.0            969987.0
# 55  2016        2.705         41213.0           392550.0           1048857.0
# 56  2017        2.155         41188.0           416830.0           1079536.0
# 57  2018        1.653         39024.0           441110.0            993216.0
# 58  2019        1.900         40064.0           477530.0           1042124.0
# 59  2020        1.959         46358.0           505863.0           1086432.0
# 60  2021        3.046         40979.0           534191.0           1134090.0
#
#     ImportTons
# 0        49.00
# 1        20.00
# 2         0.00
# 3         1.00
# 4         0.00
# 5         0.00
# 6         0.00
# 7         0.00
# 8         0.00
# 9         0.00
# 10        0.00
# 11        0.00
# 12        0.00
# 13        0.00
# 14        0.00
# 15        0.00
# 16        0.00
# 17        0.00
# 18        0.00
# 19        0.00
# 20        0.00
# 21        0.00
# 22       59.00
# 23        8.00
# 24        3.00
# 25      127.00
# 26       28.00
# 27       91.00
# 28        2.00
# 29        2.00
# 30        3.00
# 31        3.00
# 32        0.00
# 33        4.00
# 34       15.00
# 35        1.00
# 36        2.00
# 37       10.00
# 38       12.00
# 39        7.57
# 40       23.00
# 41       60.00
# 42       74.00
# 43       72.00
# 44       56.00
# 45      665.00
# 46        8.00
# 47       40.00
# 48      405.00
# 49       69.00
# 50      411.00
# 51     4713.00
# 52    14683.00
# 53    10934.47
# 54     2050.76
# 55     1382.10
# 56     1185.35
# 57      491.97
# 58     1290.55
# 59      488.38
# 60     2303.52

# %%
# Extract rows for 1991 - 2021
SetTwo = CombinedData[CombinedData['Year'] <= 2021]
SetTwo = SetTwo[CombinedData['Year'] >= 1991]
# Drop incomplete columns
SetTwo = SetTwo.drop(['WaterStressPerct'], axis=1)
# Make sure the variables are numeric
SetTwo['Yield100GperHa'] = pd.to_numeric(SetTwo['Yield100GperHa'])
SetTwo['HectaresHarvested'] = pd.to_numeric(SetTwo['HectaresHarvested'])
SetTwo['ExportValue1000USD'] = pd.to_numeric(SetTwo['ExportValue1000USD'])
SetTwo['ImportTons'] = pd.to_numeric(SetTwo['ImportTons'])
SetTwo['ProdUSDperTonne'] = pd.to_numeric(SetTwo['ProdUSDperTonne'])
SetTwo
# Out:
#     Year  TempChangeC  Yield100GperHa  HectaresHarvested  ExportValue1000USD  \
# 30  1991        0.228         22648.0           163900.0             26373.0
# 31  1992        2.217         25401.0           162280.0             30781.0
# 32  1993        0.622         21767.0           167130.0             32435.0
# 33  1994        0.346         30246.0           175230.0             43722.0
# 34  1995        1.825         16316.0           169160.0             47002.0
# 35  1996       -0.279         22258.0           173200.0             52885.0
# 36  1997        0.057         30295.0           181220.0             67533.0
# 37  1998        2.301         20838.0           188600.0             63438.0
# 38  1999        1.374         32063.0           196800.0             51408.0
# 39  2000        1.543         26342.0           202340.0            103563.0
# 40  2001        2.055         28402.0           214483.0            106329.0
# 41  2002        2.783         36275.0           220554.0            112110.0
# 42  2003        2.167         35325.0           222577.0            190452.0
# 43  2004        0.116         34074.0           230671.0            216530.0
# 44  2005        2.174         29969.0           234718.0            293287.0
# 45  2006        3.556         36049.0           234718.0            240514.0
# 46  2007        1.172         46830.0           259002.0            242532.0
# 47  2008        0.206         51238.0           275189.0            335466.0
# 48  2009        0.456         39887.0           291374.0            431156.0
# 49  2010        0.545         45371.0           311608.0            528902.0
# 50  2011        0.638         56883.0           323749.0            652397.0
# 51  2012        1.563         49871.0           331854.0            834701.0
# 52  2013        2.079         50375.0           343983.0            895132.0
# 53  2014        1.972         43897.0           352077.0            883493.0
# 54  2015        2.055         38580.0           372311.0            969987.0
# 55  2016        2.705         41213.0           392550.0           1048857.0
# 56  2017        2.155         41188.0           416830.0           1079536.0
# 57  2018        1.653         39024.0           441110.0            993216.0
# 58  2019        1.900         40064.0           477530.0           1042124.0
# 59  2020        1.959         46358.0           505863.0           1086432.0
# 60  2021        3.046         40979.0           534191.0           1134090.0
#
#     ImportTons  ProdUSDperTonne
# 30        3.00           1571.0
# 31        3.00           1716.0
# 32        0.00           2561.0
# 33        4.00           1769.0
# 34       15.00           3274.0
# 35        1.00           2838.0
# 36        2.00           2059.0
# 37       10.00           3109.0
# 38       12.00           1896.0
# 39        7.57           2138.0
# 40       23.00           2006.0
# 41       60.00           2447.0
# 42       74.00           3461.0
# 43       72.00           4872.0
# 44       56.00           6195.0
# 45      665.00           4542.0
# 46        8.00           3858.0
# 47       40.00           3197.0
# 48      405.00           3638.0
# 49       69.00           3946.0
# 50      411.00           4387.0
# 51     4713.00           5688.0
# 52    14683.00           7077.0
# 53    10934.47           8818.0
# 54     2050.76           6900.0
# 55     1382.10           5269.0
# 56     1185.35           5578.0
# 57      491.97           5512.0
# 58     1290.55           5357.0
# 59      488.38           3769.9
# 60     2303.52           3880.1

# %%
# Extract rows for 2000 - 2020
SetThree = CombinedData[CombinedData['Year'] <= 2020]
SetThree = SetThree[CombinedData['Year'] >= 2000]
# Make sure the variables are numeric
SetThree['Yield100GperHa'] = pd.to_numeric(SetThree['Yield100GperHa'])
SetThree['HectaresHarvested'] = pd.to_numeric(SetThree['HectaresHarvested'])
SetThree['ExportValue1000USD'] = pd.to_numeric(SetThree['ExportValue1000USD'])
SetThree['ImportTons'] = pd.to_numeric(SetThree['ImportTons'])
SetThree['ProdUSDperTonne'] = pd.to_numeric(SetThree['ProdUSDperTonne'])
SetThree['WaterStressPerct'] = pd.to_numeric(SetThree['WaterStressPerct'])
SetThree
# Out:
#     Year  TempChangeC  Yield100GperHa  HectaresHarvested  ExportValue1000USD  \
# 39  2000        1.543         26342.0           202340.0            103563.0
# 40  2001        2.055         28402.0           214483.0            106329.0
# 41  2002        2.783         36275.0           220554.0            112110.0
# 42  2003        2.167         35325.0           222577.0            190452.0
# 43  2004        0.116         34074.0           230671.0            216530.0
# 44  2005        2.174         29969.0           234718.0            293287.0
# 45  2006        3.556         36049.0           234718.0            240514.0
# 46  2007        1.172         46830.0           259002.0            242532.0
# 47  2008        0.206         51238.0           275189.0            335466.0
# 48  2009        0.456         39887.0           291374.0            431156.0
# 49  2010        0.545         45371.0           311608.0            528902.0
# 50  2011        0.638         56883.0           323749.0            652397.0
# 51  2012        1.563         49871.0           331854.0            834701.0
# 52  2013        2.079         50375.0           343983.0            895132.0
# 53  2014        1.972         43897.0           352077.0            883493.0
# 54  2015        2.055         38580.0           372311.0            969987.0
# 55  2016        2.705         41213.0           392550.0           1048857.0
# 56  2017        2.155         41188.0           416830.0           1079536.0
# 57  2018        1.653         39024.0           441110.0            993216.0
# 58  2019        1.900         40064.0           477530.0           1042124.0
# 59  2020        1.959         46358.0           505863.0           1086432.0
#
#     ImportTons  ProdUSDperTonne  WaterStressPerct
# 39        7.57           2138.0             10.54
# 40       23.00           2006.0             10.51
# 41       60.00           2447.0             10.47
# 42       74.00           3461.0             10.43
# 43       72.00           4872.0             10.39
# 44       56.00           6195.0             10.35
# 45      665.00           4542.0             10.19
# 46        8.00           3858.0             10.04
# 47       40.00           3197.0              9.88
# 48      405.00           3638.0              9.72
# 49       69.00           3946.0              9.57
# 50      411.00           4387.0              9.87
# 51     4713.00           5688.0             10.17
# 52    14683.00           7077.0             10.49
# 53    10934.47           8818.0             10.83
# 54     2050.76           6900.0             11.17
# 55     1382.10           5269.0             11.17
# 56     1185.35           5578.0             11.17
# 57      491.97           5512.0             11.17
# 58     1290.55           5357.0             11.17
# 59      488.38           3769.9             11.17

# %% [markdown]
# # Data Exploration

# %% [markdown]
# ## Trends

# %% [markdown]
# ### Temperature

# %%
plt.plot(SetOne['Year'], SetOne['TempChangeC'])
plt.xlabel('Year') 
plt.ylabel('Degrees of Temperature Change (Celcius)') 
plt.title('Temperature Change Over Time')
plt.show()

# %%
plt.boxplot(SetOne['TempChangeC'])
plt.xlabel('Temperature Change')
plt.ylabel('Degrees of Temperature Change (Celsius)')
plt.title('Temperature Change Distribution')
plt.show()

# %% [markdown]
# ### Yield

# %%
plt.plot(SetOne['Year'], SetOne['Yield100GperHa'])
plt.xlabel('Year') 
plt.ylabel('Crop Yield (100 grams per hectare)') 
plt.title('Yield Over Time')
plt.show()

# %%
plt.boxplot(SetOne['Yield100GperHa'])
plt.xlabel('Crop Yield')
plt.ylabel('Yield (100 grams per hectare)')
plt.title('Yield Distribution')
plt.show()

# %% [markdown]
# ### Hectares Harvested

# %%
plt.plot(SetOne['Year'], SetOne['HectaresHarvested'])
plt.xlabel('Year') 
plt.ylabel('Hectares Harvested') 
plt.title('Hectares Harvested Over Time')
plt.show()

# %%
plt.boxplot(SetOne['HectaresHarvested'])
plt.xlabel('Year') 
plt.ylabel('Hectares Harvested') 
plt.title('Hectares Harvested Over Time')
plt.show()

# %% [markdown]
# ### Export Value

# %%
plt.plot(SetOne['Year'], SetOne['ExportValue1000USD'])
plt.xlabel('Year') 
plt.ylabel('Export Value ($1000)') 
plt.title('Export Value Over Time')
plt.show()

# %%
plt.boxplot(SetOne['ExportValue1000USD'])
plt.xlabel('Year') 
plt.ylabel('Export Value ($1000)') 
plt.title('Export Value Over Time')
plt.show()

# %% [markdown]
# ### Import

# %%
plt.plot(SetOne['Year'], SetOne['ImportTons'])
plt.xlabel('Year') 
plt.ylabel('Imports (tons)') 
plt.title('Imports Over Time')
plt.show()

# %%
plt.boxplot(SetOne['ImportTons'])
plt.xlabel('Year') 
plt.ylabel('Imports (tons)') 
plt.title('Imports Over Time')
plt.show()

# %% [markdown]
# ### Producer Price Per Tonne

# %%
plt.plot(SetTwo['Year'], SetTwo['ProdUSDperTonne'])
plt.xlabel('Year') 
plt.ylabel('Producer Price ($/tonne)') 
plt.title('Producer Price Over Time')
plt.show()

# %%
plt.boxplot(SetTwo['ProdUSDperTonne'])
plt.xlabel('Year') 
plt.ylabel('Producer Price ($/tonne)') 
plt.title('Producer Price Over Time')
plt.show()

# %% [markdown]
# ### Water Stress

# %%
plt.plot(SetThree['Year'], SetThree['WaterStressPerct'])
plt.xlabel('Year') 
plt.ylabel('Water Stress (%)') 
plt.title('Agricultural Water Stress Over Time')
plt.xticks(SetThree['Year'], [f'{int(x):.0f}' for x in SetThree['Year']], rotation = 45)
plt.show()

# %%
plt.boxplot(SetThree['WaterStressPerct'])
plt.xlabel('Year') 
plt.ylabel('Water Stress (%)') 
plt.title('Agricultural Water Stress Over Time')
plt.show()

# %% [markdown]
# ## Correlation Matrixes

# %%
# Create triangular heat map of the correlations between variables to see highly correlated ones.
matrix1 = SetOne.corr()

# Define a mask to hide the upper portion of the heat map with the mirrored values
mask1 = np.triu(np.ones_like(matrix1, dtype=np.bool))

# Build and color plot
heatmap1 = sns.heatmap(matrix1, mask=mask1, annot=True, cmap="YlGnBu")
heatmap1.set_title('Correlation Matrix 1 Heatmap', fontdict={'fontsize':12})
# Out:
# Text(0.5, 1.0, 'Correlation Matrix 1 Heatmap')

# %%
# Create triangular heat map of the correlations between variables to see highly correlated ones.
matrix2 = SetTwo.corr()

# Define a mask to hide the upper portion of the heat map with the mirrored values
mask2 = np.triu(np.ones_like(matrix2, dtype=np.bool))

# Build and color plot
heatmap2 = sns.heatmap(matrix2, mask=mask2, annot=True, cmap="YlGnBu")
heatmap2.set_title('Correlation Matrix 2 Heatmap', fontdict={'fontsize':12})
# Out:
# Text(0.5, 1.0, 'Correlation Matrix 2 Heatmap')

# %%
# Create triangular heat map of the correlations between variables to see highly correlated ones.
matrix3 = SetThree.corr()

# Define a mask to hide the upper portion of the heat map with the mirrored values
mask3 = np.triu(np.ones_like(matrix3, dtype=np.bool))

# Build and color plot
heatmap3 = sns.heatmap(matrix3, mask=mask3, annot=True, cmap="YlGnBu")
heatmap3.set_title('Correlation Matrix 3 Heatmap', fontdict={'fontsize':12})
# Out:
# Text(0.5, 1.0, 'Correlation Matrix 3 Heatmap')

# %% [markdown]
# ## Time Series Forecasting Models

# %%
# Load Necessary libraries for models 
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_absolute_error, mean_squared_error
import statsmodels.api as sm
import itertools
from statsmodels.tools.sm_exceptions import ConvergenceWarning
# Disable the specific warning
warnings.filterwarnings("ignore", message="Maximum Likelihood optimization failed to converge. Check mle_retvals", category=ConvergenceWarning)
warnings.filterwarnings("ignore", message="An unsupported index was provided and will be ignored when e.g. forecasting.", category=UserWarning)

# %%
# Prepare the Data for SetOne and SetTwo
SetOne.set_index(SetOne['Year'], inplace=True)
SetTwo.set_index(SetTwo['Year'], inplace=True)

# %%
# Train-Test Split for SetOne
train_SetOne = SetOne 
test_SetOne = SetOne
# Train-Test Split for SetTwe
train_SetTwo = SetTwo  
test_SetTwo = SetTwo

# %%
# Determine best ARIMA Order for SetOne
best_aic_SetOne = np.inf
best_order_SetOne = None

for p in range(3):
    for d in range(2):
        for q in range(3):
            try:
                model = sm.tsa.ARIMA(SetOne['Year'], order=(p, d, q))
                results = model.fit()
                if results.aic < best_aic_SetOne:
                    best_aic_SetOne = results.aic
                    best_order_SetOne = (p, d, q)
            except:
                continue

print('Best ARIMA order for SetOne:', best_order_SetOne)
print('Best AIC for SetOne:', best_aic_SetOne)
# Out:
# Best ARIMA order for SetOne: (2, 1, 1)
# Best AIC for SetOne: -786.406115350926

# %%
# Determine best ARIMA Order for SetTwo
best_aic_SetTwo = np.inf
best_order_SetTwo = None

for p in range(3):
    for d in range(2):
        for q in range(3):
            try:
                model = sm.tsa.ARIMA(SetTwo['Year'], order=(p, d, q))
                results = model.fit()
                if results.aic < best_aic_SetTwo:
                    best_aic_SetTwo = results.aic
                    best_order_SetTwo = (p, d, q)
            except:
                continue

print("Best ARIMA order for SetTwo:", best_order_SetTwo)
print("Best AIC for SetTwo:", best_aic_SetTwo)
# Out:
# Best ARIMA order for SetTwo: (2, 1, 2)
# Best AIC for SetTwo: -403.62076839729343

# %% [markdown]
# Best order for SetOne & SetTwo to use in ARIMA model are as follows:
# - Best ARIMA order for SetOne: (2, 1, 1)
# - Best ARIMA order for SetTwo: (2, 1, 2)

# %%
# ARIMA models for SetOne
model_SetOne = {}
results_SetOne = {}

for col in train_SetOne.columns:
    model_SetOne = sm.tsa.ARIMA(train_SetOne[col], order=(2, 1, 1))
    results_SetOne[col] = model_SetOne.fit()

# ARIMA models for SetTwo
model_SetTwo = {}
results_SetTwo = {}

for col in train_SetTwo.columns:
    model_SetTwo = sm.tsa.ARIMA(train_SetTwo[col], order=(2, 1, 2))
    results_SetTwo[col] = model_SetTwo.fit()

# Print the results for SetOne
for col, result in results_SetOne.items():
    print(f"Results for {col}: ")
    print(result.summary())
    print("---------------------------")

# Print the results for SetTwo
for col, result in results_SetTwo.items():
    print(f"Results for {col}: ")
    print(result.summary())
    print("---------------------------")
# Out:
# Results for Year:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                   Year   No. Observations:                   61
# Model:                 ARIMA(2, 1, 1)   Log Likelihood                 397.203
# Date:                Sat, 29 Jul 2023   AIC                           -786.406
# Time:                        14:50:08   BIC                           -778.029
# Sample:                             0   HQIC                          -783.129
#                                  - 61
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.0023   6.67e-07   3461.138      0.000       0.002       0.002
# ar.L2          0.9977   6.67e-07    1.5e+06      0.000       0.998       0.998
# ma.L1          0.9946   7.85e-12   1.27e+11      0.000       0.995       0.995
# sigma2      8.669e-08   2.26e-08      3.837      0.000    4.24e-08    1.31e-07
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):              8137.33
# Prob(Q):                              1.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.00   Skew:                             7.55
# Prob(H) (two-sided):                  0.00   Kurtosis:                        58.02
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 2.13e+26. Standard errors may be unstable.
# ---------------------------
# Results for TempChangeC:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:            TempChangeC   No. Observations:                   61
# Model:                 ARIMA(2, 1, 1)   Log Likelihood                 -95.376
# Date:                Sat, 29 Jul 2023   AIC                            198.751
# Time:                        14:50:08   BIC                            207.129
# Sample:                             0   HQIC                           202.028
#                                  - 61
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.1086      0.163     -0.667      0.505      -0.428       0.210
# ar.L2         -0.1970      0.139     -1.417      0.157      -0.470       0.076
# ma.L1         -0.7553      0.139     -5.438      0.000      -1.028      -0.483
# sigma2         1.3769      0.295      4.671      0.000       0.799       1.955
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                 0.94
# Prob(Q):                              0.97   Prob(JB):                         0.62
# Heteroskedasticity (H):               0.56   Skew:                             0.13
# Prob(H) (two-sided):                  0.20   Kurtosis:                         2.44
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ---------------------------
# Results for Yield100GperHa:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:         Yield100GperHa   No. Observations:                   61
# Model:                 ARIMA(2, 1, 1)   Log Likelihood                -599.805
# Date:                Sat, 29 Jul 2023   AIC                           1207.610
# Time:                        14:50:08   BIC                           1215.987
# Sample:                             0   HQIC                          1210.887
#                                  - 61
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -1.1798      0.164     -7.201      0.000      -1.501      -0.859
# ar.L2         -0.5895      0.123     -4.789      0.000      -0.831      -0.348
# ma.L1          0.7949      0.146      5.450      0.000       0.509       1.081
# sigma2      3.013e+07   6.58e-10   4.58e+16      0.000    3.01e+07    3.01e+07
# ===================================================================================
# Ljung-Box (L1) (Q):                   1.62   Jarque-Bera (JB):                 0.32
# Prob(Q):                              0.20   Prob(JB):                         0.85
# Heteroskedasticity (H):               2.98   Skew:                            -0.15
# Prob(H) (two-sided):                  0.02   Kurtosis:                         3.21
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 1.37e+33. Standard errors may be unstable.
# ---------------------------
# Results for HectaresHarvested:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:      HectaresHarvested   No. Observations:                   61
# Model:                 ARIMA(2, 1, 1)   Log Likelihood                -613.772
# Date:                Sat, 29 Jul 2023   AIC                           1235.544
# Time:                        14:50:08   BIC                           1243.921
# Sample:                             0   HQIC                          1238.821
#                                  - 61
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          1.2597      0.230      5.484      0.000       0.809       1.710
# ar.L2         -0.2871      0.194     -1.482      0.138      -0.667       0.093
# ma.L1         -0.7856      0.215     -3.658      0.000      -1.207      -0.365
# sigma2      2.988e+07   1.58e-08   1.89e+15      0.000    2.99e+07    2.99e+07
# ===================================================================================
# Ljung-Box (L1) (Q):                   1.97   Jarque-Bera (JB):                24.89
# Prob(Q):                              0.16   Prob(JB):                         0.00
# Heteroskedasticity (H):               2.00   Skew:                             0.05
# Prob(H) (two-sided):                  0.13   Kurtosis:                         6.15
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 4.34e+30. Standard errors may be unstable.
# ---------------------------
# Results for ExportValue1000USD:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:     ExportValue1000USD   No. Observations:                   61
# Model:                 ARIMA(2, 1, 1)   Log Likelihood                -716.400
# Date:                Sat, 29 Jul 2023   AIC                           1440.800
# Time:                        14:50:08   BIC                           1449.177
# Sample:                             0   HQIC                          1444.077
#                                  - 61
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          1.1974      0.306      3.908      0.000       0.597       1.798
# ar.L2         -0.2274      0.232     -0.980      0.327      -0.682       0.227
# ma.L1         -0.8105      0.236     -3.435      0.001      -1.273      -0.348
# sigma2      1.469e+09   1.81e-10    8.1e+18      0.000    1.47e+09    1.47e+09
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                33.99
# Prob(Q):                              0.96   Prob(JB):                         0.00
# Heteroskedasticity (H):            1854.16   Skew:                            -0.42
# Prob(H) (two-sided):                  0.00   Kurtosis:                         6.59
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 8.2e+34. Standard errors may be unstable.
# ---------------------------
# Results for ImportTons:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:             ImportTons   No. Observations:                   61
# Model:                 ARIMA(2, 1, 1)   Log Likelihood                -526.117
# Date:                Sat, 29 Jul 2023   AIC                           1060.234
# Time:                        14:50:08   BIC                           1068.611
# Sample:                             0   HQIC                          1063.511
#                                  - 61
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.1843      0.158     -1.166      0.244      -0.494       0.126
# ar.L2         -0.3593      0.130     -2.770      0.006      -0.614      -0.105
# ma.L1          0.7217      0.145      4.972      0.000       0.437       1.006
# sigma2      2.748e+06    2.2e+05     12.493      0.000    2.32e+06    3.18e+06
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.06   Jarque-Bera (JB):               545.73
# Prob(Q):                              0.81   Prob(JB):                         0.00
# Heteroskedasticity (H):          115099.19   Skew:                             1.47
# Prob(H) (two-sided):                  0.00   Kurtosis:                        17.48
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ---------------------------
# Results for Year:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                   Year   No. Observations:                   31
# Model:                 ARIMA(2, 1, 2)   Log Likelihood                 206.810
# Date:                Sat, 29 Jul 2023   AIC                           -403.621
# Time:                        14:50:08   BIC                           -396.615
# Sample:                             0   HQIC                          -401.379
#                                  - 31
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.0020      0.017      0.114      0.909      -0.032       0.036
# ar.L2          0.9980      0.017     57.827      0.000       0.964       1.032
# ma.L1          1.9881      0.016    121.252      0.000       1.956       2.020
# ma.L2          0.9957      0.016     60.985      0.000       0.964       1.028
# sigma2      2.928e-08   4.19e-08      0.699      0.485   -5.28e-08    1.11e-07
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):               918.58
# Prob(Q):                              0.99   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.00   Skew:                             5.20
# Prob(H) (two-sided):                  0.00   Kurtosis:                        28.03
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 8.26e+16. Standard errors may be unstable.
# ---------------------------
# Results for TempChangeC:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:            TempChangeC   No. Observations:                   31
# Model:                 ARIMA(2, 1, 2)   Log Likelihood                 -36.153
# Date:                Sat, 29 Jul 2023   AIC                             82.305
# Time:                        14:50:08   BIC                             89.311
# Sample:                             0   HQIC                            84.546
#                                  - 31
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.5172      0.234     -2.211      0.027      -0.976      -0.059
# ar.L2         -0.5115      0.268     -1.906      0.057      -1.038       0.014
# ma.L1          0.4246      0.359      1.184      0.236      -0.278       1.128
# ma.L2         -0.4426      0.339     -1.306      0.191      -1.107       0.221
# sigma2         0.5985      0.245      2.444      0.015       0.119       1.078
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                 1.43
# Prob(Q):                              0.98   Prob(JB):                         0.49
# Heteroskedasticity (H):               0.75   Skew:                            -0.26
# Prob(H) (two-sided):                  0.66   Kurtosis:                         2.06
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ---------------------------
# Results for Yield100GperHa:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:         Yield100GperHa   No. Observations:                   31
# Model:                 ARIMA(2, 1, 2)   Log Likelihood                -300.702
# Date:                Sat, 29 Jul 2023   AIC                            611.403
# Time:                        14:50:08   BIC                            618.409
# Sample:                             0   HQIC                           613.644
#                                  - 31
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -1.2078      0.272     -4.433      0.000      -1.742      -0.674
# ar.L2         -0.6116      0.191     -3.197      0.001      -0.986      -0.237
# ma.L1          1.2467      0.391      3.187      0.001       0.480       2.013
# ma.L2          0.3147      0.365      0.863      0.388      -0.400       1.030
# sigma2      2.999e+07   1.38e-09   2.17e+16      0.000       3e+07       3e+07
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.85   Jarque-Bera (JB):                 0.66
# Prob(Q):                              0.36   Prob(JB):                         0.72
# Heteroskedasticity (H):               0.53   Skew:                            -0.17
# Prob(H) (two-sided):                  0.33   Kurtosis:                         2.35
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 1.75e+33. Standard errors may be unstable.
# ---------------------------
# Results for HectaresHarvested:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:      HectaresHarvested   No. Observations:                   31
# Model:                 ARIMA(2, 1, 2)   Log Likelihood                -323.001
# Date:                Sat, 29 Jul 2023   AIC                            656.002
# Time:                        14:50:08   BIC                            663.008
# Sample:                             0   HQIC                           658.243
#                                  - 31
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.0007      0.004      0.160      0.873      -0.008       0.009
# ar.L2          0.9993      0.003    290.630      0.000       0.993       1.006
# ma.L1         -0.0033      0.184     -0.018      0.986      -0.363       0.357
# ma.L2         -0.9960      0.167     -5.953      0.000      -1.324      -0.668
# sigma2      5.002e+07   7.02e-09   7.13e+15      0.000       5e+07       5e+07
# ===================================================================================
# Ljung-Box (L1) (Q):                  13.22   Jarque-Bera (JB):                 0.55
# Prob(Q):                              0.00   Prob(JB):                         0.76
# Heteroskedasticity (H):               3.17   Skew:                             0.24
# Prob(H) (two-sided):                  0.08   Kurtosis:                         2.54
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 1.78e+31. Standard errors may be unstable.
# ---------------------------
# Results for ExportValue1000USD:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:     ExportValue1000USD   No. Observations:                   31
# Model:                 ARIMA(2, 1, 2)   Log Likelihood                -369.154
# Date:                Sat, 29 Jul 2023   AIC                            748.308
# Time:                        14:50:08   BIC                            755.314
# Sample:                             0   HQIC                           750.549
#                                  - 31
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.6990      1.658      0.422      0.673      -2.550       3.948
# ar.L2          0.2271      1.367      0.166      0.868      -2.452       2.906
# ma.L1         -0.2725      1.537     -0.177      0.859      -3.285       2.740
# ma.L2         -0.3629      0.727     -0.499      0.618      -1.789       1.063
# sigma2      3.857e+09   2.38e-10   1.62e+19      0.000    3.86e+09    3.86e+09
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.07   Jarque-Bera (JB):                 2.21
# Prob(Q):                              0.80   Prob(JB):                         0.33
# Heteroskedasticity (H):              10.90   Skew:                            -0.59
# Prob(H) (two-sided):                  0.00   Kurtosis:                         3.60
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 3.45e+36. Standard errors may be unstable.
# ---------------------------
# Results for ImportTons:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:             ImportTons   No. Observations:                   31
# Model:                 ARIMA(2, 1, 2)   Log Likelihood                -271.245
# Date:                Sat, 29 Jul 2023   AIC                            552.490
# Time:                        14:50:08   BIC                            559.496
# Sample:                             0   HQIC                           554.731
#                                  - 31
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.4333      0.729      0.594      0.552      -0.996       1.862
# ar.L2         -0.1560      1.039     -0.150      0.881      -2.192       1.880
# ma.L1         -0.1047      0.583     -0.180      0.858      -1.248       1.039
# ma.L2         -0.7260      0.336     -2.159      0.031      -1.385      -0.067
# sigma2      3.985e+06   1.08e+06      3.683      0.000    1.86e+06    6.11e+06
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):               152.24
# Prob(Q):                              0.94   Prob(JB):                         0.00
# Heteroskedasticity (H):          115315.65   Skew:                             2.67
# Prob(H) (two-sided):                  0.00   Kurtosis:                        12.66
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# ---------------------------
# Results for ProdUSDperTonne:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:        ProdUSDperTonne   No. Observations:                   31
# Model:                 ARIMA(2, 1, 2)   Log Likelihood                -248.903
# Date:                Sat, 29 Jul 2023   AIC                            507.807
# Time:                        14:50:08   BIC                            514.813
# Sample:                             0   HQIC                           510.048
#                                  - 31
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.0345      0.538      0.064      0.949      -1.020       1.089
# ar.L2          0.4532      0.512      0.884      0.376      -0.551       1.457
# ma.L1          0.1556      0.632      0.246      0.806      -1.083       1.394
# ma.L2         -0.8390      0.505     -1.662      0.097      -1.829       0.151
# sigma2      8.654e+05   7.07e-07   1.22e+12      0.000    8.65e+05    8.65e+05
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.03   Jarque-Bera (JB):                 0.98
# Prob(Q):                              0.86   Prob(JB):                         0.61
# Heteroskedasticity (H):               1.68   Skew:                            -0.02
# Prob(H) (two-sided):                  0.42   Kurtosis:                         2.12
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 1.02e+29. Standard errors may be unstable.
# ---------------------------

# %%
# Forecast and Evaluate
forecast_SetOne = {}
forecast_SetTwo = {}

# Forecast for SetOne
for col, model in results_SetOne.items():
    forecast_SetOne[col] = model.forecast(steps=len(test_SetOne))

# Forecast for SetTwo
for col, model in results_SetTwo.items():
    forecast_SetTwo[col] = model.forecast(steps=len(test_SetTwo))
    
# Print the forecasts for SetOne
print("Forecast for SetOne:")
for col, forecast in forecast_SetOne.items():
    print(f"Column '{col}': ")
    print(forecast)

# Print the forecasts for SetTwo
print("\nForecast for SetTwo:")
for col, forecast in forecast_SetTwo.items():
    print(f"Column '{col}': ")
    print(forecast)
# Out:
# Forecast for SetOne:
# Column 'Year':
# 61     2021.999997
# 62     2022.999992
# 63     2023.999985
# 64     2024.999975
# 65     2025.999962
# 66     2026.999947
# 67     2027.999929
# 68     2028.999909
# 69     2029.999886
# 70     2030.999860
# 71     2031.999832
# 72     2032.999802
# 73     2033.999769
# 74     2034.999733
# 75     2035.999695
# 76     2036.999655
# 77     2037.999612
# 78     2038.999566
# 79     2039.999518
# 80     2040.999467
# 81     2041.999414
# 82     2042.999358
# 83     2043.999299
# 84     2044.999238
# 85     2045.999175
# 86     2046.999109
# 87     2047.999040
# 88     2048.998969
# 89     2049.998896
# 90     2050.998820
# 91     2051.998741
# 92     2052.998660
# 93     2053.998576
# 94     2054.998490
# 95     2055.998401
# 96     2056.998309
# 97     2057.998215
# 98     2058.998119
# 99     2059.998020
# 100    2060.997918
# 101    2061.997814
# 102    2062.997708
# 103    2063.997598
# 104    2064.997487
# 105    2065.997373
# 106    2066.997256
# 107    2067.997136
# 108    2068.997015
# 109    2069.996890
# 110    2070.996763
# 111    2071.996634
# 112    2072.996502
# 113    2073.996367
# 114    2074.996230
# 115    2075.996091
# 116    2076.995948
# 117    2077.995804
# 118    2078.995657
# 119    2079.995507
# 120    2080.995354
# 121    2081.995200
# Name: predicted_mean, dtype: float64
# Column 'TempChangeC':
# 61     2.046000
# 62     1.940483
# 63     2.148924
# 64     2.147072
# 65     2.106214
# 66     2.111016
# 67     2.118543
# 68     2.116779
# 69     2.115488
# 70     2.115976
# 71     2.116177
# 72     2.116059
# 73     2.116032
# 74     2.116058
# 75     2.116061
# 76     2.116055
# 77     2.116056
# 78     2.116057
# 79     2.116057
# 80     2.116056
# 81     2.116056
# 82     2.116056
# 83     2.116056
# 84     2.116056
# 85     2.116056
# 86     2.116056
# 87     2.116056
# 88     2.116056
# 89     2.116056
# 90     2.116056
# 91     2.116056
# 92     2.116056
# 93     2.116056
# 94     2.116056
# 95     2.116056
# 96     2.116056
# 97     2.116056
# 98     2.116056
# 99     2.116056
# 100    2.116056
# 101    2.116056
# 102    2.116056
# 103    2.116056
# 104    2.116056
# 105    2.116056
# 106    2.116056
# 107    2.116056
# 108    2.116056
# 109    2.116056
# 110    2.116056
# 111    2.116056
# 112    2.116056
# 113    2.116056
# 114    2.116056
# 115    2.116056
# 116    2.116056
# 117    2.116056
# 118    2.116056
# 119    2.116056
# 120    2.116056
# 121    2.116056
# Name: predicted_mean, dtype: float64
# Column 'Yield100GperHa':
# 61     41897.942652
# 62     43984.678828
# 63     40981.020077
# 64     43294.627643
# 65     42335.670694
# 66     42103.186601
# 67     42942.776011
# 68     42089.272334
# 69     42601.304723
# 70     42500.344634
# 71     42317.615837
# 72     42592.716144
# 73     42375.869434
# 74     42469.535374
# 75     42486.858458
# 76     42411.204687
# 77     42490.249534
# 78     42441.589705
# 79     42452.402076
# 80     42468.330452
# 81     42443.164187
# 82     42463.465750
# 83     42454.349309
# 84     42453.137207
# 85     42459.941377
# 86     42452.628309
# 87     42457.245265
# 88     42456.109192
# 89     42454.727851
# 90     42457.027278
# 91     42455.128698
# 92     42456.013146
# 93     42456.088878
# 94     42455.478149
# 95     42456.154047
# 96     42455.716642
# 97     42455.834255
# 98     42455.953344
# 99     42455.743509
# 100    42455.920871
# 101    42455.835316
# 102    42455.831700
# 103    42455.886401
# 104    42455.823996
# 105    42455.865375
# 106    42455.853343
# 107    42455.843146
# 108    42455.862270
# 109    42455.845718
# 110    42455.853972
# 111    42455.853991
# 112    42455.849103
# 113    42455.854859
# 114    42455.850950
# 115    42455.852169
# 116    42455.853035
# 117    42455.851294
# 118    42455.852837
# 119    42455.852043
# 120    42455.852071
# 121    42455.852506
# Name: predicted_mean, dtype: float64
# Column 'HectaresHarvested':
# 61     5.569871e+05
# 62     5.775697e+05
# 63     5.969525e+05
# 64     6.154591e+05
# 65     6.332065e+05
# 66     6.502493e+05
# 67     6.666224e+05
# 68     6.823540e+05
# 69     6.974701e+05
# 70     7.119948e+05
# 71     7.259514e+05
# 72     7.393621e+05
# 73     7.522482e+05
# 74     7.646303e+05
# 75     7.765281e+05
# 76     7.879606e+05
# 77     7.989458e+05
# 78     8.095014e+05
# 79     8.196441e+05
# 80     8.293901e+05
# 81     8.387549e+05
# 82     8.477534e+05
# 83     8.563999e+05
# 84     8.647082e+05
# 85     8.726916e+05
# 86     8.803627e+05
# 87     8.877337e+05
# 88     8.948164e+05
# 89     9.016222e+05
# 90     9.081617e+05
# 91     9.144454e+05
# 92     9.204833e+05
# 93     9.262851e+05
# 94     9.318599e+05
# 95     9.372167e+05
# 96     9.423640e+05
# 97     9.473099e+05
# 98     9.520624e+05
# 99     9.566290e+05
# 100    9.610169e+05
# 101    9.652333e+05
# 102    9.692847e+05
# 103    9.731777e+05
# 104    9.769183e+05
# 105    9.805127e+05
# 106    9.839665e+05
# 107    9.872852e+05
# 108    9.904741e+05
# 109    9.935382e+05
# 110    9.964825e+05
# 111    9.993117e+05
# 112    1.002030e+06
# 113    1.004642e+06
# 114    1.007152e+06
# 115    1.009564e+06
# 116    1.011882e+06
# 117    1.014108e+06
# 118    1.016248e+06
# 119    1.018304e+06
# 120    1.020280e+06
# 121    1.022178e+06
# Name: predicted_mean, dtype: float64
# Column 'ExportValue1000USD':
# 61     1.170183e+06
# 62     1.202565e+06
# 63     1.233134e+06
# 64     1.262374e+06
# 65     1.290437e+06
# 66     1.317392e+06
# 67     1.343287e+06
# 68     1.368165e+06
# 69     1.392067e+06
# 70     1.415032e+06
# 71     1.437095e+06
# 72     1.458292e+06
# 73     1.478658e+06
# 74     1.498225e+06
# 75     1.517023e+06
# 76     1.535084e+06
# 77     1.552437e+06
# 78     1.569108e+06
# 79     1.585126e+06
# 80     1.600514e+06
# 81     1.615299e+06
# 82     1.629504e+06
# 83     1.643152e+06
# 84     1.656263e+06
# 85     1.668861e+06
# 86     1.680964e+06
# 87     1.692592e+06
# 88     1.703764e+06
# 89     1.714498e+06
# 90     1.724810e+06
# 91     1.734718e+06
# 92     1.744237e+06
# 93     1.753382e+06
# 94     1.762168e+06
# 95     1.770610e+06
# 96     1.778721e+06
# 97     1.786513e+06
# 98     1.794000e+06
# 99     1.801192e+06
# 100    1.808103e+06
# 101    1.814742e+06
# 102    1.821121e+06
# 103    1.827249e+06
# 104    1.833137e+06
# 105    1.838794e+06
# 106    1.844229e+06
# 107    1.849451e+06
# 108    1.854468e+06
# 109    1.859288e+06
# 110    1.863919e+06
# 111    1.868368e+06
# 112    1.872643e+06
# 113    1.876749e+06
# 114    1.880695e+06
# 115    1.884486e+06
# 116    1.888128e+06
# 117    1.891627e+06
# 118    1.894989e+06
# 119    1.898219e+06
# 120    1.901322e+06
# 121    1.904304e+06
# Name: predicted_mean, dtype: float64
# Column 'ImportTons':
# 61     4296.925423
# 62     3277.385336
# 63     2749.040016
# 64     3212.729015
# 65     3317.112419
# 66     3131.271928
# 67     3128.014773
# 68     3195.387737
# 69     3184.142096
# 70     3162.007330
# 71     3170.127045
# 72     3176.583738
# 73     3172.476432
# 74     3170.913457
# 75     3172.677252
# 76     3172.913787
# 77     3172.236463
# 78     3172.276298
# 79     3172.512320
# 80     3172.454512
# 81     3172.380362
# 82     3172.414797
# 83     3172.435093
# 84     3172.418980
# 85     3172.414657
# 86     3172.421243
# 87     3172.421583
# 88     3172.419154
# 89     3172.419480
# 90     3172.420292
# 91     3172.420026
# 92     3172.419783
# 93     3172.419923
# 94     3172.419985
# 95     3172.419923
# 96     3172.419912
# 97     3172.419936
# 98     3172.419936
# 99     3172.419927
# 100    3172.419929
# 101    3172.419932
# 102    3172.419931
# 103    3172.419930
# 104    3172.419930
# 105    3172.419930
# 106    3172.419930
# 107    3172.419930
# 108    3172.419930
# 109    3172.419930
# 110    3172.419930
# 111    3172.419930
# 112    3172.419930
# 113    3172.419930
# 114    3172.419930
# 115    3172.419930
# 116    3172.419930
# 117    3172.419930
# 118    3172.419930
# 119    3172.419930
# 120    3172.419930
# 121    3172.419930
# Name: predicted_mean, dtype: float64
#
# Forecast for SetTwo:
# Column 'Year':
# 31    2021.999999
# 32    2022.999996
# 33    2023.999992
# 34    2024.999986
# 35    2025.999978
# 36    2026.999968
# 37    2027.999957
# 38    2028.999943
# 39    2029.999929
# 40    2030.999912
# 41    2031.999894
# 42    2032.999873
# 43    2033.999852
# 44    2034.999828
# 45    2035.999803
# 46    2036.999776
# 47    2037.999747
# 48    2038.999716
# 49    2039.999684
# 50    2040.999650
# 51    2041.999614
# 52    2042.999577
# 53    2043.999537
# 54    2044.999496
# 55    2045.999454
# 56    2046.999409
# 57    2047.999363
# 58    2048.999315
# 59    2049.999265
# 60    2050.999214
# 61    2051.999161
# Name: predicted_mean, dtype: float64
# Column 'TempChangeC':
# 31    2.712944
# 32    1.941286
# 33    2.510734
# 34    2.610976
# 35    2.267835
# 36    2.394016
# 37    2.504293
# 38    2.382714
# 39    2.389178
# 40    2.448028
# 41    2.414286
# 42    2.401632
# 43    2.425437
# 44    2.419599
# 45    2.410441
# 46    2.418164
# 47    2.418855
# 48    2.414547
# 49    2.416421
# 50    2.417655
# 51    2.416058
# 52    2.416253
# 53    2.416969
# 54    2.416499
# 55    2.416376
# 56    2.416680
# 57    2.416586
# 58    2.416479
# 59    2.416582
# 60    2.416584
# 61    2.416530
# Name: predicted_mean, dtype: float64
# Column 'Yield100GperHa':
# 31    40556.618973
# 32    43212.626462
# 33    40262.977281
# 34    42201.243493
# 35    41664.128872
# 36    41127.453937
# 37    42104.149161
# 38    41252.701671
# 39    41683.763854
# 40    41683.850677
# 41    41420.115441
# 42    41738.606174
# 43    41515.223763
# 44    41590.245211
# 45    41636.249970
# 46    41534.802798
# 47    41629.196655
# 48    41577.229556
# 49    41582.266595
# 50    41607.964977
# 51    41573.845473
# 52    41599.338884
# 53    41589.414430
# 54    41585.810011
# 55    41596.233117
# 56    41585.848317
# 57    41592.016656
# 58    41590.917602
# 59    41588.472606
# 60    41592.097876
# 61    41589.214532
# Name: predicted_mean, dtype: float64
# Column 'HectaresHarvested':
# 31    545126.369688
# 32    558723.221140
# 33    569660.473854
# 34    583255.412038
# 35    594194.545069
# 36    607787.572694
# 37    618728.583338
# 38    632319.703104
# 39    643262.588660
# 40    656851.803267
# 41    667796.561038
# 42    681383.873181
# 43    692330.500475
# 44    705915.912845
# 45    716864.406971
# 46    730447.922256
# 47    741398.280530
# 48    754979.901412
# 49    765932.121152
# 50    779511.850312
# 51    790465.928841
# 52    804043.768953
# 53    814999.703597
# 54    828575.657335
# 55    839533.445423
# 56    853107.515454
# 57    864067.154321
# 58    877639.343310
# 59    888600.830293
# 60    902171.140900
# 61    913134.473340
# Name: predicted_mean, dtype: float64
# Column 'ExportValue1000USD':
# 31    1.170531e+06
# 32    1.197164e+06
# 33    1.224057e+06
# 34    1.248902e+06
# 35    1.272377e+06
# 36    1.294427e+06
# 37    1.315171e+06
# 38    1.334679e+06
# 39    1.353025e+06
# 40    1.370280e+06
# 41    1.386507e+06
# 42    1.401767e+06
# 43    1.416120e+06
# 44    1.429618e+06
# 45    1.442312e+06
# 46    1.454250e+06
# 47    1.465478e+06
# 48    1.476037e+06
# 49    1.485968e+06
# 50    1.495307e+06
# 51    1.504091e+06
# 52    1.512351e+06
# 53    1.520120e+06
# 54    1.527426e+06
# 55    1.534297e+06
# 56    1.540759e+06
# 57    1.546836e+06
# 58    1.552552e+06
# 59    1.557927e+06
# 60    1.562983e+06
# 61    1.567737e+06
# Name: predicted_mean, dtype: float64
# Column 'ImportTons':
# 31    4257.063172
# 32    3166.745108
# 33    2389.534479
# 34    2222.939014
# 35    2272.036440
# 36    2319.303350
# 37    2332.120692
# 38    2330.298343
# 39    2327.508803
# 40    2326.584589
# 41    2326.619449
# 42    2326.778765
# 43    2326.842350
# 44    2326.845038
# 45    2326.836281
# 46    2326.832068
# 47    2326.831609
# 48    2326.832068
# 49    2326.832338
# 50    2326.832383
# 51    2326.832361
# 52    2326.832344
# 53    2326.832340
# 54    2326.832341
# 55    2326.832342
# 56    2326.832343
# 57    2326.832343
# 58    2326.832343
# 59    2326.832343
# 60    2326.832343
# 61    2326.832343
# Name: predicted_mean, dtype: float64
# Column 'ProdUSDperTonne':
# 31    4505.272350
# 32    4295.185076
# 33    4571.240024
# 34    4485.557961
# 35    4607.698829
# 36    4573.083726
# 37    4627.238743
# 38    4613.420328
# 39    4637.484407
# 40    4632.052397
# 41    4642.769828
# 42    4640.677888
# 43    4645.462404
# 44    4644.679430
# 45    4646.820556
# 46    4646.539586
# 47    4647.500158
# 48    4647.405962
# 49    4647.838002
# 50    4647.810216
# 51    4648.005038
# 52    4647.999166
# 53    4648.087248
# 54    4648.087624
# 55    4648.127552
# 56    4648.129100
# 57    4648.147247
# 58    4648.148574
# 59    4648.156843
# 60    4648.157730
# 61    4648.161507
# Name: predicted_mean, dtype: float64
# C:\Users\SBenavidez\PycharmProjects\pythonProject\venv\lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# C:\Users\SBenavidez\PycharmProjects\pythonProject\venv\lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# C:\Users\SBenavidez\PycharmProjects\pythonProject\venv\lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# C:\Users\SBenavidez\PycharmProjects\pythonProject\venv\lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# C:\Users\SBenavidez\PycharmProjects\pythonProject\venv\lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# C:\Users\SBenavidez\PycharmProjects\pythonProject\venv\lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# C:\Users\SBenavidez\PycharmProjects\pythonProject\venv\lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# C:\Users\SBenavidez\PycharmProjects\pythonProject\venv\lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# C:\Users\SBenavidez\PycharmProjects\pythonProject\venv\lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# C:\Users\SBenavidez\PycharmProjects\pythonProject\venv\lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# C:\Users\SBenavidez\PycharmProjects\pythonProject\venv\lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# C:\Users\SBenavidez\PycharmProjects\pythonProject\venv\lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# C:\Users\SBenavidez\PycharmProjects\pythonProject\venv\lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(

# %%
# Step 6: Compare Performance
mae_SetOne = {}
mse_SetOne = {}
rmse_SetOne = {}
mae_SetTwo = {}
mse_SetTwo = {}
rmse_SetTwo = {}

# Calculate metrics for SetOne
for col in test_SetOne.columns:
    mae_SetOne[col] = mean_absolute_error(test_SetOne[col], forecast_SetOne[col])
    mse_SetOne[col] = mean_squared_error(test_SetOne[col], forecast_SetOne[col])
    rmse_SetOne[col] = np.sqrt(mse_SetOne[col])
    
# Calculate metrics for SetTwo
for col in test_SetTwo.columns:
    mae_SetTwo[col] = mean_absolute_error(test_SetTwo[col], forecast_SetTwo[col])
    mse_SetTwo[col] = mean_squared_error(test_SetTwo[col], forecast_SetTwo[col])
    rmse_SetTwo[col] = np.sqrt(mse_SetTwo[col])    
    
# Print the performance metrics for SetOne
print("Performance metrics for SetOne:")
for col in test_SetOne.columns:
    print(f"Column '{col}':")
    print(f"MAE: {mae_SetOne[col]}")
    print(f"MSE: {mse_SetOne[col]}")
    print(f"RMSE: {rmse_SetOne[col]}\n")

# Print the performance metrics for SetTwo
print("Performance metrics for SetTwo:")
for col in test_SetTwo.columns:
    print(f"Column '{col}':")
    print(f"MAE: {mae_SetTwo[col]}")
    print(f"MSE: {mse_SetTwo[col]}")
    print(f"RMSE: {rmse_SetTwo[col]}\n")
# Out:
# Performance metrics for SetOne:
# Column 'Year':
# MAE: 60.99834738416368
# MSE: 3720.7983857050713
# RMSE: 60.998347401426145
#
# Column 'TempChangeC':
# MAE: 1.4578708419353583
# MSE: 3.3950941012698506
# RMSE: 1.8425781126643859
#
# Column 'Yield100GperHa':
# MAE: 16927.987844839376
# MSE: 380513669.19348294
# RMSE: 19506.75957696416
#
# Column 'HectaresHarvested':
# MAE: 678887.599733934
# MSE: 466136975621.27234
# RMSE: 682742.2468408354
#
# Column 'ExportValue1000USD':
# MAE: 1440294.6784337964
# MSE: 2157319703852.2998
# RMSE: 1468781.707352151
#
# Column 'ImportTons':
# MAE: 3183.9528074335826
# MSE: 11947662.344356297
# RMSE: 3456.53907027771
#
# Performance metrics for SetTwo:
# Column 'Year':
# MAE: 30.999706057594082
# MSE: 960.9817757235321
# RMSE: 30.999706058663396
#
# Column 'TempChangeC':
# MAE: 1.068937188337121
# MSE: 1.8340266637338767
# RMSE: 1.3542624057891723
#
# Column 'Yield100GperHa':
# MAE: 9199.188041986277
# MSE: 130007036.09855945
# RMSE: 11402.06280014978
#
# Column 'HectaresHarvested':
# MAE: 446968.01821908396
# MSE: 200797145307.0331
# RMSE: 448103.9447572774
#
# Column 'ExportValue1000USD':
# MAE: 978215.2638557679
# MSE: 1055853621201.6947
# RMSE: 1027547.3814874401
#
# Column 'ImportTons':
# MAE: 2582.0531636272826
# MSE: 11771140.967296084
# RMSE: 3430.909641377354
#
# Column 'ProdUSDperTonne':
# MAE: 1593.070284540357
# MSE: 3461365.359592391
# RMSE: 1860.474498506333

# %%
# Convert to list RMSE
rmse_SetOne_values = list(rmse_SetOne.values())
rmse_SetTwo_values = list(rmse_SetTwo.values())

# %%
# Plot the individual RMSE values for SetOne
plt.figure(figsize=(10, 6))
plt.bar(list(rmse_SetOne.keys()), rmse_SetOne_values, color='blue', label='SetOne')
plt.xlabel('Column Names')
plt.ylabel('RMSE')
plt.title('RMSE for SetOne')
plt.legend()
plt.xticks(rotation=90)
plt.show()

# %%
# Plot RMSE values for SetTwo
plt.figure(figsize=(10, 6))
plt.bar(list(rmse_SetTwo.keys()), rmse_SetTwo_values, color='orange', label='SetTwo')
plt.xlabel('Column Names')
plt.ylabel('RMSE')
plt.title('RMSE for SetTwo')
plt.legend()
plt.xticks(rotation=90)
plt.show()

# %%
# Compare mean RMSE values for SetOne and SetTwo
mean_rmse_SetOne = np.mean(rmse_SetOne_values)
mean_rmse_SetTwo = np.mean(rmse_SetTwo_values)

# Plot the mean RMSE comparison for SetOne and SetTwo
plt.figure(figsize=(8, 6))
plt.bar(['SetOne', 'SetTwo'], [mean_rmse_SetOne, mean_rmse_SetTwo], color=['blue', 'orange'])
plt.xlabel('Datasets')
plt.ylabel('Mean RMSE')
plt.title('Mean RMSE Comparison between SetOne and SetTwo')
plt.show()

# %%
# Choose the better model
if mean_rmse_SetOne < mean_rmse_SetTwo:
    print("Model for SetOne is better.")
else:
    print("Model for SetTwo is better.")
# Out:
# Model for SetTwo is better.
